# %%
import os
import numpy as np
import sys

# %%
import fabio
# Out:
# ERROR:fabio.nexus:h5py module missing

# %%
file_path = 'EmptyCapillary.sfrm'
im = fabio.open(file_path)

# %%
print(im.header)
# Out:
# {
#   "FORMAT": "100",
#   "VERSION": "1",
#   "HDRBLKS": 15,
#   "TYPE": "Unwarped Scan Frame",
#   "SITE": "Generated by the Collect package",
#   "MODEL": "EULERIAN",
#   "USER": "",
#   "SAMPLE": "",
#   "SETNAME": "",
#   "RUN": "0",
#   "SAMPNUM": "0",
#   "TITLE": "\r\n\r\n\r\n\r\n\r\n\r\n\r\n",
#   "NCOUNTS": "84752512                            0",
#   "NOVERFL": "-1                      0                       0",
#   "MINIMUM": "0",
#   "MAXIMUM": "2670",
#   "NONTIME": "0",
#   "NLATE": "0",
#   "FILENAM": "",
#   "CREATED": "09/09/2022                          09:15:28",
#   "CUMULAT": "600.220000",
#   "ELAPSDR": "0.000000",
#   "ELAPSDA": "0.000000",
#   "OSCILLA": "0",
#   "NSTEPS": "1",
#   "RANGE": "1.000000",
#   "START": "-90.000000",
#   "INCREME": "1.000000",
#   "NUMBER": "0",
#   "NFRAMES": "1",
#   "ANGLES": "-0.000000         20.000000         -90.000000        0.000000",
#   "NOVER64": "0                       0                       0",
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(im.data)
plt.show()
